# %%
# !pip install python-doctr
# !pip install "python-doctr[torch]"
# Out:
# Collecting python-doctr
#   Downloading python_doctr-0.11.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.26.4)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.13.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (3.12.1)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (4.10.0.84)
# Collecting pypdfium2<5.0.0,>=4.11.0 (from python-doctr)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.3.0.post6)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (2.0.7)
# Collecting langdetect<2.0.0,>=1.0.9 (from python-doctr)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 27.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from python-doctr)
#   Downloading rapidfuzz-3.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (0.29.0)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (11.0.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (0.7.1)
# Collecting anyascii>=0.3.2 (from python-doctr)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr) (1.17.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.16.0->python-doctr) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.16.0->python-doctr) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<3.0.0,>=1.16.0->python-doctr) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<3.0.0,>=1.16.0->python-doctr) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2025.1.31)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<3.0.0,>=1.16.0->python-doctr) (2024.2.0)
# Downloading python_doctr-0.11.0-py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.1/304.1 kB 21.1 MB/s eta 0:00:00
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 16.2 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 67.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.8 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=3cfc0f944a803ac8292511e0f036b489eabe4cddebe1d0782683830f37e2d03e
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: rapidfuzz, pypdfium2, langdetect, anyascii, python-doctr
# Successfully installed anyascii-0.3.2 langdetect-1.0.9 pypdfium2-4.30.1 python-doctr-0.11.0 rapidfuzz-3.12.2
# Requirement already satisfied: python-doctr[torch] in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (1.26.4)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (1.13.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (3.12.1)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (4.10.0.84)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.11.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (4.30.1)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (1.3.0.post6)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (2.0.7)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (1.0.9)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (0.29.0)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (11.0.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (0.7.1)
# Requirement already satisfied: anyascii>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (0.3.2)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (4.67.1)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (0.20.1+cu121)
# Requirement already satisfied: onnx<3.0.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[torch]) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[torch]) (1.17.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr[torch]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr[torch]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr[torch]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr[torch]) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr[torch]) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.16.0->python-doctr[torch]) (2.4.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr[torch]) (3.20.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch]) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.0.0->python-doctr[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->python-doctr[torch]) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.16.0->python-doctr[torch]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.16.0->python-doctr[torch]) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<3.0.0,>=1.16.0->python-doctr[torch]) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<3.0.0,>=1.16.0->python-doctr[torch]) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch]) (2025.1.31)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<3.0.0,>=1.16.0->python-doctr[torch]) (2024.2.0)

# %%
import os
import glob
import json
from doctr.io import DocumentFile
from doctr.models import ocr_predictor, kie_predictor

# Initialize models
ocr_model = ocr_predictor(det_arch='db_resnet50', reco_arch='vitstr_small', pretrained=True)
kie_model = kie_predictor(det_arch='db_resnet50', reco_arch='crnn_vgg16_bn', pretrained=True)

# Define input and output base directories
input_base = '/kaggle/input/find-it-again-dataset/findit2'  # adjust this to your input folder path
output_base = '/kaggle/working/doctr_output'         # adjust this to your desired output folder path

# Ensure output subfolders exist
for subfolder in ['train', 'test', 'val']:
    os.makedirs(os.path.join(output_base, subfolder), exist_ok=True)

# Process images in each subfolder
for subfolder in ['train', 'test', 'val']:
    input_folder = os.path.join(input_base, subfolder)
    
    # List image files; adjust extensions if needed
    image_paths = (glob.glob(os.path.join(input_folder, '*.[pP][nN][gG]')) +
                   glob.glob(os.path.join(input_folder, '*.[jJ][pP][gG]')) +
                   glob.glob(os.path.join(input_folder, '*.[jJ][pP][eE][gG]')))
    
    for image_path in image_paths:
        try:
            # Read image from file
            image = DocumentFile.from_images(image_path)
            result = ocr_model(image)
            
            # Obtain outputs
            result_json = result.export()
            string_result = result.render()
            
            # Use the input file name (without extension) for the output file names
            base_name = os.path.splitext(os.path.basename(image_path))[0]
            json_output_path = os.path.join(output_base, subfolder, f"{base_name}.json")
            text_output_path = os.path.join(output_base, subfolder, f"{base_name}.txt")
            
            # Save JSON output
            with open(json_output_path, 'w', encoding='utf-8') as json_file:
                json.dump(result_json, json_file, ensure_ascii=False, indent=4)
            
            # Save text output
            with open(text_output_path, 'w', encoding='utf-8') as text_file:
                text_file.write(string_result)
            
            print(f"Processed {image_path}")
        except Exception as e:
            print(f"Error processing {image_path}: {e}")
# Out:
# Downloading https://doctr-static.mindee.com/models?id=v0.7.0/db_resnet50-79bd7d70.pt&src=0 to /root/.cache/doctr/models/db_resnet50-79bd7d70.pt
#   0%|          | 0/102021912 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/doctr/models/utils/pytorch.py:62: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(archive_path, map_location="cpu")
# Downloading https://doctr-static.mindee.com/models?id=v0.7.0/vitstr_small-fcd12655.pt&src=0 to /root/.cache/doctr/models/vitstr_small-fcd12655.pt
#   0%|          | 0/85720631 [00:00<?, ?it/s]
# Downloading https://doctr-static.mindee.com/models?id=v0.3.1/crnn_vgg16_bn-9762b0b0.pt&src=0 to /root/.cache/doctr/models/crnn_vgg16_bn-9762b0b0.pt
#   0%|          | 0/63286381 [00:00<?, ?it/s]
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006387813.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005442379.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006556728.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006913067.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005361908.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006389898.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006556734.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005361946.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006647984.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006557187.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005719888.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005447840.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006387953.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005757201.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663274.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008099084.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005568887.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414674.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008099047.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005677328.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006913028.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005711449.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414711.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008099071.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663324.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005442384.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005705784.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005441408.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619506.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006557202.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006329402.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006556824.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008123580.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619779.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619343.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007225398.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006349081.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007103692.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006620181.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005806718.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008042787.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006466065.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414679.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619766.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619564.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007225406.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663273.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005676540.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008099086.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005447850.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005719882.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414714.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51009453804.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005746204.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006857071.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006913070.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663297.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005442346.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005806679.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006913060.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51009453729.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008042786.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005719914.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006387971.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005711444.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006334699.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005719886.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005717526.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339643.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846392.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846307.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005715451.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414713.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005605285.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005301666.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007391390.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008142034.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008114260.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619569.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005715456.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846368.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414677.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846269.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663279.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005361895.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006912959.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006857137.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005433553.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007103578.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005746140.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846379.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007391372.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005365179.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414633.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008123604.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008164996.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007135037.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005447861.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006620414.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006556723.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005441398.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846290.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008142068.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006389894.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846266.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006556823.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619570.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339159.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007103649.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339130.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619765.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006913018.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005442378.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846353.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006913054.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006349083.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006620192.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005763958.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005605332.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339658.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846286.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005301667.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414702.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006857540.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005806716.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005806719.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006679216.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007231346.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006557170.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007103681.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005711441.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006008093.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846301.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006913032.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619700.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619704.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006557161.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005711452.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005764031.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846396.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006414717.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005453802.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005724611.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005447832.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008123586.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005719863.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X00016469622.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846358.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005711442.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006389865.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008099102.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005268262.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005361912.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005705759.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339112.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005568898.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006401978.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005433494.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008114262.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006387660.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006311714.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663280.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005301659.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005676535.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005724621.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008114282.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663309.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005757308.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006401940.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006350763.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005675103.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007579719.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005663301.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339162.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006441473.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006392167.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006008081.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339151.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619566.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006619760.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005442394.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005757199.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007231331.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006387740.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X00016469670.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005763999.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007339656.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51007846360.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006912998.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008122920.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005742110.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005719855.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006556809.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006328967.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008128052.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51005757351.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51008042793.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006401853.png
# Processed /kaggle/input/find-it-again-dataset/findit2/train/X51006